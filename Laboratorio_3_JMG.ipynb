# %% [markdown]
# # Universidad Galileo
# ### Ciencia de Datos Python
# ### Jorge Mario García
#
# # Laboratorio No.03

# %% [markdown]
# ## Parte 1: Numpy

# %% [markdown]
# 1. ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
import sys

# Creación de un array de 1000 booleanos
array_booleanos = [True] * 1000

# Calculando el tamaño en bytes
tamaño_bytes = sys.getsizeof(array_booleanos)

print("El tamaño en bytes del array de 1000 elementos booleanos es:", tamaño_bytes)
# Out:
# El tamaño en bytes del array de 1000 elementos booleanos es: 8056

# %% [markdown]
# 2. Crear un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla

# %%
# Crear una lista de los enteros pares en orden decreciente en el rango [1, 100]
pares_decrecientes = [num for num in range(100, 0, -2) if num % 2 == 0]

# Mostrar los últimos 10 elementos
ultimos_10 = pares_decrecientes[-10:]
print("Los últimos 10 enteros pares en orden decreciente son:", ultimos_10)
# Out:
# Los últimos 10 enteros pares en orden decreciente son: [20, 18, 16, 14, 12, 10, 8, 6, 4, 2]

# %% [markdown]
# 3. Dado el array
# 2456 0374 8852 1561
# Seleccione con una instrucción el subarray de elementos 0374
# Después, seleccione el subarray de elementos
# 25 85

# %%
# Dado el array
cadena = "2456 0374 8852 1561"

# Seleccionar el subarray de elementos '0374'
subarray_1 = cadena[5:9]

# Seleccionar el subarray de elementos '25 85'
subarray_2 = cadena[0:2] + " " + cadena[11:13]

print("El subarray de elementos '0374' es:", subarray_1)
print("El subarray de elementos '25 85' es:", subarray_2)
# Out:
# El subarray de elementos '0374' es: 0374
# El subarray de elementos '25 85' es: 24 85

# %% [markdown]
#  4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
# Arrays
a = [1, 4, 2, 7]
b = [1, 3, 2, 9]

# Calcular la diferencia elemento a elemento
diferencia = [a[i] - b[i] for i in range(len(a))]

# Calcular la media aritmética de las diferencias
media_diferencia = sum(diferencia) / len(diferencia)

print("La media aritmética de la diferencia (a - b) es:", media_diferencia)
# Out:
# La media aritmética de la diferencia (a - b) es: -0.25

# %% [markdown]
# 5. Tengo valores de cordenadas (x, y) en las columnas del array
#    1.33 4.5
#    30.0 10.7
#    70.2 0.5
# Agregue a este array las coordenadas (37.1, -3.6). Muestre en pantalla las dimensiones del nuevo

# %%
import numpy as np

# Array original
array_original = np.array([[1.33, 4.5],
                            [30.0, 10.7],
                            [70.2, 0.5]])

# Coordenadas a agregar
coordenadas_nuevas = np.array([[37.1, -3.6]])

# Agregar las coordenadas nuevas al array original
array_nuevo = np.append(array_original, coordenadas_nuevas, axis=0)

# Mostrar las dimensiones del nuevo array
print("Dimensiones del nuevo array:", array_nuevo.shape)
# Out:
# Dimensiones del nuevo array: (4, 2)

# %% [markdown]
# 6. Copie el array del ejercicio anterior. Traspóngalo (. Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0)

# %%
import numpy as np

# Array original
array_original = np.array([[1.33, 4.5],
                            [30.0, 10.7],
                            [70.2, 0.5]])

# Copiar el array original y transponerlo
array_transpuesto = array_original.T.copy()

# Agregar dos nuevos pares de coordenadas
coordenadas_nuevas = np.array([[10.8, 3.0],
                               [35.8, 12.0]])

# Agregar las coordenadas nuevas al array transpuesto
array_transpuesto = np.append(array_transpuesto, coordenadas_nuevas, axis=1)

# Mostrar las dimensiones del nuevo array transpuesto
print("Dimensiones del nuevo array transpuesto:", array_transpuesto.shape)
# Out:
# Dimensiones del nuevo array transpuesto: (2, 5)

# %% [markdown]
# # PARTE 2 Exploración y Minería de Datos:
#
# Con el dataset nucleospoblacion.csv adjunto al laboratorio, luego responda las siguientes preguntas usando pandas y matplotlib.

# %% [markdown]
# 1. ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Contar los municipios con más de 100,000 habitantes
municipios_mas_de_100k = df[df['Poblacion'] > 100000]
cantidad_municipios_mas_de_100k = municipios_mas_de_100k.shape[0]

print("Cantidad de municipios con más de 100,000 habitantes:", cantidad_municipios_mas_de_100k)
# Out:
# Cantidad de municipios con más de 100,000 habitantes: 62

# %% [markdown]
# Realice una gráfica de barras sobre la población de cada ciudad, ordenela de menor a mayor y responda:
#
# a. ¿Cuál es la segunda ciudad más poblada?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Ordenar el DataFrame por población de menor a mayor
df_sorted = df.sort_values(by='Poblacion', ascending=False)

# Crear la gráfica de barras
plt.figure(figsize=(10, 40))
plt.barh(df_sorted['Municipio'], df_sorted['Poblacion'], color='green')
plt.xlabel('Población')
plt.ylabel('Municipio')
plt.title('Población de cada municipio (de menor a mayor)')
plt.grid(axis='x')

# Mostrar la gráfica
plt.show()

# Determinar la segunda ciudad más poblada
segunda_ciudad_mas_poblada = df_sorted.iloc[-2]['Municipio']
poblacion_segunda_ciudad_mas_poblada = df_sorted.iloc[-2]['Poblacion']

print("La segunda ciudad más poblada es:", segunda_ciudad_mas_poblada)
print("Población de la segunda ciudad más poblada:", poblacion_segunda_ciudad_mas_poblada)
# Out:
# La segunda ciudad más poblada es: Caldas de Reis
# Población de la segunda ciudad más poblada: 10045.0

# %% [markdown]
# ¿Qué posición ocupa Granada en el ranking de
# las ciudades más pobladas?

# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Ordenar el DataFrame por población de mayor a menor
df_sorted = df.sort_values(by='Poblacion', ascending=False)

# Encontrar la posición de Granada en el ranking
posicion_granada = df_sorted[df_sorted['Municipio'] == 'Granada'].index[0] + 1

print("Granada ocupa la posición número:", posicion_granada)
# Out:
# Granada ocupa la posición número: 273

# %% [markdown]
# 3) ¿Cuántos municipios de Navarra tienen más de 5000 habitantes?

# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Filtrar los municipios de Navarra
municipios_navarra = df[df['Provincia'] == 'Navarra']

# Contar los municipios de Navarra con más de 5000 habitantes
municipios_mas_de_5000 = municipios_navarra[municipios_navarra['Poblacion'] > 5000]
cantidad_municipios_mas_de_5000 = municipios_mas_de_5000.shape[0]

print("Cantidad de municipios de Navarra con más de 5000 habitantes:", cantidad_municipios_mas_de_5000)
# Out:
# Cantidad de municipios de Navarra con más de 5000 habitantes: 11

# %% [markdown]
# 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Encontrar el municipio situado más al norte
municipio_mas_al_norte = df[df['Y'] == df['Y'].max()]

# Extraer información relevante
nombre_municipio = municipio_mas_al_norte['Municipio'].iloc[0]
provincia = municipio_mas_al_norte['Provincia'].iloc[0]
poblacion = municipio_mas_al_norte['Poblacion'].iloc[0]

print("El municipio más al norte es:", nombre_municipio)
print("Provincia:", provincia)
print("Población:", poblacion)
# Out:
# El municipio más al norte es: Viveiro
# Provincia: Lugo
# Población: 16211.0

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Filtrar los municipios de la provincia de Granada
municipios_granada = df[df['Provincia'] == 'Granada']

# Calcular las estadísticas de población
media_poblacion = municipios_granada['Poblacion'].mean()
mediana_poblacion = municipios_granada['Poblacion'].median()
desviacion_estandar_poblacion = municipios_granada['Poblacion'].std()
maximo_poblacion = municipios_granada['Poblacion'].max()
minimo_poblacion = municipios_granada['Poblacion'].min()

# Imprimir los resultados
print("Datos estadísticos de Granada")
print("Media de la población:", media_poblacion)
print("Mediana de la población:", mediana_poblacion)
print("Desviación estándar de la población:", desviacion_estandar_poblacion)
print("Valor máximo de la población:", maximo_poblacion)
print("Valor mínimo de la población:", minimo_poblacion)
# Out:
# Datos estadísticos de Granada
# Media de la población: 30217.85
# Mediana de la población: 17526.0
# Desviación estándar de la población: 50355.49171459277
# Valor máximo de la población: 239154.0
# Valor mínimo de la población: 10386.0

# %% [markdown]
# 6. Realice un histograma con la población de los Municipios para cada una de las provincias.

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Cargar el archivo CSV en un DataFrame
# df = pd.read_csv("nucleospoblacion.csv")
#
# # Crear un histograma para la población de los municipios por provincia
# plt.figure(figsize=(12, 8))
# df.groupby('Provincia')['Poblacion'].plot(kind='hist', alpha=0.5, bins=20)
# plt.xlabel('Población')
# plt.ylabel('Frecuencia')
# plt.title('Histograma de población de municipios por provincia')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de entre los diponibles en el archivo. Asegúrese de que no se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
import pandas as pd
import random

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv("nucleospoblacion.csv")

# Obtener la cantidad total de municipios
total_municipios = len(df)

# Seleccionar al azar cincuenta municipios diferentes sin repetición
indices_aleatorios = random.sample(range(total_municipios), 50)
municipios_aleatorios = df.iloc[indices_aleatorios]

# Calcular el promedio y la desviación estándar de la población de estos cincuenta municipios
promedio_poblacion = municipios_aleatorios['Poblacion'].mean()
desviacion_estandar_poblacion = municipios_aleatorios['Poblacion'].std()

# Imprimir los resultados
print("Promedio de la población de los cincuenta municipios seleccionados al azar:", promedio_poblacion)
print("Desviación estándar de la población de los cincuenta municipios seleccionados al azar:", desviacion_estandar_poblacion)
# Out:
# Promedio de la población de los cincuenta municipios seleccionados al azar: 63987.04
# Desviación estándar de la población de los cincuenta municipios seleccionados al azar: 144982.31452427118

# %% [markdown]
# 8) Determine los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero.

# %%
from math import radians, sin, cos, sqrt, atan2

# Coordenadas geográficas de Madrid (latitud y longitud en grados decimales)
madrid_lat = radians(40.4168)
madrid_lon = radians(-3.7038)

# Función para calcular la distancia entre dos puntos en la Tierra utilizando la fórmula de Haversine
def haversine(lon1, lat1, lon2, lat2):
    # Radio de la Tierra en kilómetros
    R = 6371.0
    
    # Diferencia de latitud y longitud
    dlon = lon2 - lon1
    dlat = lat2 - lat1

    # Fórmula de Haversine
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Distancia en kilómetros
    distance = R * c
    return distance

# Calcular distancias entre Madrid y todos los municipios excepto Madrid
distancias = []
for index, row in df.iterrows():
    if row['Municipio'] != 'Madrid':  # Excluir Madrid
        municipio_lat = radians(row['Y'])
        municipio_lon = radians(row['X'])
        distancia = haversine(madrid_lon, madrid_lat, municipio_lon, municipio_lat)
        distancias.append((row['Municipio'], distancia))

# Encontrar el municipio más cercano y el más lejano a Madrid
municipio_mas_cercano = min(distancias, key=lambda x: x[1])
municipio_mas_lejano = max(distancias, key=lambda x: x[1])

print("El municipio más cercano a Madrid es:", municipio_mas_cercano[0], "con una distancia de", municipio_mas_cercano[1], "kilómetros.")
print("El municipio más lejano a Madrid es:", municipio_mas_lejano[0], "con una distancia de", municipio_mas_lejano[1], "kilómetros.")
# Out:
# El municipio más cercano a Madrid es: Pozuelo de Alarcón con una distancia de 6.90584703479936 kilómetros.
# El municipio más lejano a Madrid es: Los Llanos de Aridane con una distancia de 1840.2348172017023 kilómetros.
